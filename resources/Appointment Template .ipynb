# %%
import json
import datetime
from datetime import date
import jdatetime

# %%
template_str = '''{
   "public_holidays":[
        {
            "year": 1399,
            "month": 12,
            "day": 26
        },
        {
            "year": 1398,
            "month": 1,
            "day": 29
        }
        
   ],
   "days":[
      {
         "label":"\u0634\u0646\u0628\u0647",
         "value":6,
         "active":true,
         "slots":[
            {
               "start":"0830",
               "end":"1000",
               "number_of_appointments":100
            },
            {
               "start":"1030",
               "end":"1200",
               "number_of_appointments":100
            },
            {
               "start":"1300",
               "end":"1400",
               "number_of_appointments":100
            },
            {
               "start":"1430",
               "end":"1530",
               "number_of_appointments":100
            }
         ],
         "times":[
            {
               "from_value":"1600",
               "from_label":"16:00",
               "to_value":"1600",
               "to_label":"16:00"
            },
            {
               "from_value":"1630",
               "from_label":"16:30",
               "to_value":"1630",
               "to_label":"16:30"
            },
            {
               "from_value":"1700",
               "from_label":"17:00",
               "to_value":"1700",
               "to_label":"17:00"
            },
            {
               "from_value":"1730",
               "from_label":"17:30",
               "to_value":"1730",
               "to_label":"17:30"
            },
            {
               "from_value":"1800",
               "from_label":"18:00",
               "to_value":"1800",
               "to_label":"18:00"
            },
            {
               "from_value":"1830",
               "from_label":"18:30",
               "to_value":"1830",
               "to_label":"18:30"
            }
         ],
         "slot":{
            "start":null,
            "end":null
         }
      },
      {
         "label":"\u06cc\u06a9 \u0634\u0646\u0628\u0647",
         "value":7,
         "active":true,
         "slots":[
            {
               "start":"0830",
               "end":"1000",
               "number_of_appointments":100
            },
            {
               "start":"1030",
               "end":"1200",
               "number_of_appointments":100
            },
            {
               "start":"1300",
               "end":"1400",
               "number_of_appointments":100
            },
            {
               "start":"1430",
               "end":"1530",
               "number_of_appointments":100
            }
         ],
         "times":[
            {
               "from_value":7,
               "from_label":"7:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":8,
               "to_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":8,
               "from_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":9,
               "to_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":9,
               "from_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":10,
               "to_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":10,
               "from_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":11,
               "to_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":11,
               "from_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":12,
               "to_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":12,
               "from_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":13,
               "to_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":13,
               "from_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":14,
               "to_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":14,
               "from_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":15,
               "to_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":15,
               "from_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":16,
               "to_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":16,
               "from_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":17,
               "to_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":17,
               "from_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":18,
               "to_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":18,
               "from_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":19,
               "to_label":"7:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            }
         ]
      },
      {
         "label":"\u062f\u0648\u0634\u0646\u0628\u0647",
         "value":1,
         "active":true,
         "slots":[
            {
               "start":"0830",
               "end":"1000",
               "number_of_appointments":100
            },
            {
               "start":"1030",
               "end":"1200",
               "number_of_appointments":100
            },
            {
               "start":"1300",
               "end":"1400",
               "number_of_appointments":100
            },
            {
               "start":"1430",
               "end":"1530",
               "number_of_appointments":100
            }
         ],
         "times":[
            {
               "from_value":7,
               "from_label":"7:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":8,
               "to_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":8,
               "from_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":9,
               "to_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":9,
               "from_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":10,
               "to_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":10,
               "from_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":11,
               "to_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":11,
               "from_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":12,
               "to_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":12,
               "from_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":13,
               "to_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":13,
               "from_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":14,
               "to_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":14,
               "from_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":15,
               "to_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":15,
               "from_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":16,
               "to_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":16,
               "from_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":17,
               "to_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":17,
               "from_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":18,
               "to_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":18,
               "from_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":19,
               "to_label":"7:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            }
         ]
      },
      {
         "label":"\u0633\u0647 \u0634\u0646\u0628\u0647",
         "value":2,
         "active":true,
         "slots":[
            {
               "start":"0830",
               "end":"1000",
               "number_of_appointments":100
            },
            {
               "start":"1030",
               "end":"1200",
               "number_of_appointments":100
            },
            {
               "start":"1300",
               "end":"1400",
               "number_of_appointments":100
            },
            {
               "start":"1430",
               "end":"1530",
               "number_of_appointments":100
            }
         ],
         "times":[
            {
               "from_value":7,
               "from_label":"7:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":8,
               "to_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":8,
               "from_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":9,
               "to_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":9,
               "from_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":10,
               "to_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":10,
               "from_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":11,
               "to_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":11,
               "from_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":12,
               "to_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":12,
               "from_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":13,
               "to_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":13,
               "from_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":14,
               "to_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":14,
               "from_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":15,
               "to_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":15,
               "from_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":16,
               "to_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":16,
               "from_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":17,
               "to_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":17,
               "from_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":18,
               "to_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":18,
               "from_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":19,
               "to_label":"7:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            }
         ]
      },
      {
         "label":"\u0686\u0647\u0627\u0631 \u0634\u0646\u0628\u0647",
         "value":3,
         "active":true,
         "slots":[
            {
               "start":"0830",
               "end":"1000",
               "number_of_appointments":100
            },
            {
               "start":"1030",
               "end":"1200",
               "number_of_appointments":100
            },
            {
               "start":"1300",
               "end":"1400",
               "number_of_appointments":100
            },
            {
               "start":"1430",
               "end":"1530",
               "number_of_appointments":100
            }
         ],
         "times":[
            {
               "from_value":7,
               "from_label":"7:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":8,
               "to_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":8,
               "from_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":9,
               "to_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":9,
               "from_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":10,
               "to_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":10,
               "from_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":11,
               "to_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":11,
               "from_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":12,
               "to_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":12,
               "from_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":13,
               "to_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":13,
               "from_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":14,
               "to_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":14,
               "from_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":15,
               "to_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":15,
               "from_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":16,
               "to_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":16,
               "from_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":17,
               "to_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":17,
               "from_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":18,
               "to_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":18,
               "from_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":19,
               "to_label":"7:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            }
         ]
      },
      {
         "label":"\u067e\u0646\u062c\u0634\u0646\u0628\u0647",
         "value":4,
         "active":true,
         "slots":[
            {
               "start":"0830",
               "end":"1100",
               "number_of_appointments":100
            },
            {
               "start":"1130",
               "end":"1330",
               "number_of_appointments":100
            }
         ],
         "times":[
            {
               "from_value":"1400",
               "from_label":"14:00",
               "to_value":"1400",
               "to_label":"14:00"
            },
            {
               "from_value":"1430",
               "from_label":"14:30",
               "to_value":"1430",
               "to_label":"14:30"
            },
            {
               "from_value":"1500",
               "from_label":"15:00",
               "to_value":"1500",
               "to_label":"15:00"
            },
            {
               "from_value":"1530",
               "from_label":"15:30",
               "to_value":"1530",
               "to_label":"15:30"
            },
            {
               "from_value":"1600",
               "from_label":"16:00",
               "to_value":"1600",
               "to_label":"16:00"
            },
            {
               "from_value":"1630",
               "from_label":"16:30",
               "to_value":"1630",
               "to_label":"16:30"
            },
            {
               "from_value":"1700",
               "from_label":"17:00",
               "to_value":"1700",
               "to_label":"17:00"
            },
            {
               "from_value":"1730",
               "from_label":"17:30",
               "to_value":"1730",
               "to_label":"17:30"
            },
            {
               "from_value":"1800",
               "from_label":"18:00",
               "to_value":"1800",
               "to_label":"18:00"
            },
            {
               "from_value":"1830",
               "from_label":"18:30",
               "to_value":"1830",
               "to_label":"18:30"
            }
         ],
         "slot":{
            "start":null,
            "end":null
         }
      },
      {
         "label":"\u062c\u0645\u0639\u0647",
         "value":5,
         "active":false,
         "slots":[

         ],
         "times":[
            {
               "from_value":7,
               "from_label":"7:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":8,
               "to_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":8,
               "from_label":"8:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":9,
               "to_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":9,
               "from_label":"9:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":10,
               "to_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":10,
               "from_label":"10:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":11,
               "to_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":11,
               "from_label":"11:00 \u0642\u0628\u0644 \u0627\u0632 \u0638\u0647\u0631",
               "to_value":12,
               "to_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":12,
               "from_label":"12:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":13,
               "to_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":13,
               "from_label":"1:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":14,
               "to_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":14,
               "from_label":"2:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":15,
               "to_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":15,
               "from_label":"3:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":16,
               "to_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":16,
               "from_label":"4:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":17,
               "to_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":17,
               "from_label":"5:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":18,
               "to_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            },
            {
               "from_value":18,
               "from_label":"6:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631",
               "to_value":19,
               "to_label":"7:00 \u0628\u0639\u062f \u0627\u0632 \u0638\u0647\u0631"
            }
         ]
      }
   ]
}'''

# %%
def load_json_object(jsonstr):
    return json.loads(jsonstr)

# %%
def load_public_holidays(jsonobj):
    public_holidays =[]
    holidays = jsonobj['public_holidays']
    print(holidays)
    for hd in holidays:
#         print(hd['month'])
        date = jdatetime.date(1399,1,12,locale='fa_IR')
        public_holidays.append(date)
    
    return public_holidays

# %%
def is_public_holiday(date):
# Out:
#   File "<ipython-input-138-35e9547fe097>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def load_appointment_by_date(date):
# Out:
#   File "<ipython-input-139-c67eed147fde>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
def load_available_appointments(jsonobj):
    total_tries =0
    today = date.today()
    appointments = []
    
#     while len(appointments) != 15 && total_tries < 1000:
        
    um = HijriDate()
    print(um.year)

# %%
jsonobj = load_json_object(template_str)
jsonobj
# Out:
# {'public_holidays': [{'year': 1399, 'month': 12, 'day': 26},
#   {'year': 1398, 'month': 1, 'day': 29}],
#  'days': [{'label': 'شنبه',
#    'value': 6,
#    'active': True,
#    'slots': [{'start': '0830', 'end': '1000', 'number_of_appointments': 100},
#     {'start': '1030', 'end': '1200', 'number_of_appointments': 100},
#     {'start': '1300', 'end': '1400', 'number_of_appointments': 100},
#     {'start': '1430', 'end': '1530', 'number_of_appointments': 100}],
#    'times': [{'from_value': '1600',
#      'from_label': '16:00',
#      'to_value': '1600',
#      'to_label': '16:00'},
#     {'from_value': '1630',
#      'from_label': '16:30',
#      'to_value': '1630',
#      'to_label': '16:30'},
#     {'from_value': '1700',
#      'from_label': '17:00',
#      'to_value': '1700',
#      'to_label': '17:00'},
#     {'from_value': '1730',
#      'from_label': '17:30',
#      'to_value': '1730',
#      'to_label': '17:30'},
#     {'from_value': '1800',
#      'from_label': '18:00',
# ...

# %%
load_available_appointments(jsonobj)
# Out:
# -1

# %%
load_public_holidays(jsonobj)
# Out:
# [{'year': 1399, 'month': 12, 'day': 26}, {'year': 1398, 'month': 1, 'day': 29}]
# [jdatetime.date(1399, 1, 12), jdatetime.date(1399, 1, 12)]

# %%
# create the object with Gregorian date
um = HijriDate(2017, 12, 26, gr=True)

# hijri month
print('hijri month: ', um.month)  # 4
# Hijri year
print('hijri year: ', um.year)  # 1439
# arabic day name
print('arabic day name: ', um.day_name)  # الثلاثاء
# english day name
print('english day name: ', um.day_name_en)  # Tuesday
# arabic hijri month name
print('arabic hijri month name: ', um.month_name)  # ربيع الثاني
# english gregorian month name
print('english gregorian month name: ', um.month_name_gr)  # December
# gregorian year
print('gregorian year: ', um.year_gr)  # 2017
# gregorian month
print('gregorian month: ', um.month_gr)  # 12
# gregorian day
print('gregorian day: ', um.day_gr)  # 26

# current hijri month
print('current_month: ', HijriDate.current_month())  # 4
# the gregorian date corresponding to the first day of the given hijri month/year
print('first day: ', HijriDate.month_start_date(4))  # 2017-12-19
print('first day: ', HijriDate.month_start_date(4, 1439))  # 2017-12-19
# the gregorian date corresponding to the last day of the given hijri month/year
print('last day: ', HijriDate.month_end_date(4))   # 2018-01-17
print('last day: ', HijriDate.month_end_date(4, 1439))   # 2018-01-17
# the hijri month for the given gregorian date
print('hijri month: ', HijriDate.hijri_month_from_date(date.today()))  # 4
# the hijri year for the given gregorian date
print('hijri year: ', HijriDate.hijri_year_from_date(date.today()))  # 1439
# convert the given gregorian date to hijri date
print('hijri date: ', HijriDate.get_hijri_date(date.today()))  # 1439-04-08
# convert the given hijri date to gregorian date
print('georing date: ', HijriDate.get_georing_date('1439-04-08'))  # 2017-12-26
# Out:
# hijri month:  4
# hijri year:  1439
# arabic day name:  الثلاثاء
# english day name:  Tuesday
# arabic hijri month name:  ربيع الثاني
# english gregorian month name:  December
# gregorian year:  2017
# gregorian month:  12
# gregorian day:  26
# current_month:  10
# first day:  2019-11-28
# first day:  2017-12-19
# last day:  2019-12-27
# last day:  2018-01-17
# hijri month:  10
# hijri year:  1441
# hijri date:  1441-10-15
# georing date:  2017-12-26
